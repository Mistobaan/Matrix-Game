# %% [markdown]
# # Overview
#
# We utilize various techniques to speed up the real-time inference for H100

# %%
# !nsys --help
# Out:
# /bin/bash: line 1: nsys: command not found

# %%
# !nsys profile \
		--output=nsys.profile \
	    --stats true \
        -t cuda,nvtx \
		 python train.py
